# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-1.4.1.tar.gz (185 kB)
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# Installing collected packages: emoji
#     Running setup.py install for emoji: started
#     Running setup.py install for emoji: finished with status 'done'
# Successfully installed emoji-1.4.1
# WARNING: You are using pip version 20.2.3; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\ayan\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import emoji

# %%
emoji.EMOJI_UNICODE
# Out:
# {':1st_place_medal:': '🥇',
#  ':2nd_place_medal:': '🥈',
#  ':3rd_place_medal:': '🥉',
#  ':AB_button_(blood_type):': '🆎',
#  ':ATM_sign:': '🏧',
#  ':A_button_(blood_type):': '🅰',
#  ':A_button_(blood_type)_selector:': '🅰️',
#  ':Afghanistan:': '🇦🇫',
#  ':Aland_Islands:': '🇦🇽',
#  ':Albania:': '🇦🇱',
#  ':Algeria:': '🇩🇿',
#  ':American_Samoa:': '🇦🇸',
#  ':Andorra:': '🇦🇩',
#  ':Angola:': '🇦🇴',
#  ':Anguilla:': '🇦🇮',
#  ':Antarctica:': '🇦🇶',
#  ':Antigua_&_Barbuda:': '🇦🇬',
#  ':Aquarius:': '♒',
#  ':Argentina:': '🇦🇷',
#  ':Aries:': '♈',
#  ':Armenia:': '🇦🇲',
#  ':Aruba:': '🇦🇼',
#  ':Ascension_Island:': '🇦🇨',
#  ':Australia:': '🇦🇺',
#  ':Austria:': '🇦🇹',
#  ':Azerbaijan:': '🇦🇿',
#  ':BACK_arrow:': '🔙',
#  ':B_button_(blood_type):': '🅱',
#  ':B_button_(blood_type)_selector:': '🅱️',
#  ':Bahamas:': '🇧🇸',
#  ':Bahrain:': '🇧🇭',
#  ':Bangladesh:': '🇧🇩',
#  ':Barbados:': '🇧🇧',
#  ':Belarus:': '🇧🇾',
#  ':Belgium:': '🇧🇪',
#  ':Belize:': '🇧🇿',
#  ':Benin:': '🇧🇯',
#  ':Bermuda:': '🇧🇲',
#  ':Bhutan:': '🇧🇹',
#  ':Bolivia:': '🇧🇴',
#  ':Bosnia_&_Herzegovina:': '🇧🇦',
#  ':Botswana:': '🇧🇼',
#  ':Bouvet_Island:': '🇧🇻',
#  ':Brazil:': '🇧🇷',
#  ':British_Indian_Ocean_Territory:': '🇮🇴',
#  ':British_Virgin_Islands:': '🇻🇬',
#  ':Brunei:': '🇧🇳',
#  ':Bulgaria:': '🇧🇬',
#  ':Burkina_Faso:': '🇧🇫',
#  ':Burundi:': '🇧🇮',
#  ':CL_button:': '🆑',
#  ':COOL_button:': '🆒',
#  ':Cambodia:': '🇰🇭',
#  ':Cameroon:': '🇨🇲',
#  ':Canada:': '🇨🇦',
#  ':Canary_Islands:': '🇮🇨',
#  ':Cancer:': '♋',
#  ':Cape_Verde:': '🇨🇻',
#  ':Capricorn:': '♑',
#  ':Caribbean_Netherlands:': '🇧🇶',
#  ':Cayman_Islands:': '🇰🇾',
#  ':Central_African_Republic:': '🇨🇫',
#  ':Ceuta_&_Melilla:': '🇪🇦',
#  ':Chad:': '🇹🇩',
#  ':Chile:': '🇨🇱',
#  ':China:': '🇨🇳',
#  ':Christmas_Island:': '🇨🇽',
#  ':Christmas_tree:': '🎄',
#  ':Clipperton_Island:': '🇨🇵',
#  ':Cocos_(Keeling)_Islands:': '🇨🇨',
#  ':Colombia:': '🇨🇴',
#  ':Comoros:': '🇰🇲',
#  ':Congo_-_Brazzaville:': '🇨🇬',
#  ':Congo_-_Kinshasa:': '🇨🇩',
#  ':Cook_Islands:': '🇨🇰',
#  ':Costa_Rica:': '🇨🇷',
#  ':Croatia:': '🇭🇷',
#  ':Cuba:': '🇨🇺',
#  ':Curaçao:': '🇨🇼',
#  ':Cyprus:': '🇨🇾',
#  ':Czechia:': '🇨🇿',
#  ':Côte_d’Ivoire:': '🇨🇮',
#  ':Denmark:': '🇩🇰',
#  ':Diego_Garcia:': '🇩🇬',
#  ':Djibouti:': '🇩🇯',
#  ':Dominica:': '🇩🇲',
#  ':Dominican_Republic:': '🇩🇴',
#  ':END_arrow:': '🔚',
#  ':Ecuador:': '🇪🇨',
#  ':Egypt:': '🇪🇬',
#  ':El_Salvador:': '🇸🇻',
#  ':England:': '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#  ':Equatorial_Guinea:': '🇬🇶',
#  ':Eritrea:': '🇪🇷',
#  ':Estonia:': '🇪🇪',
#  ':Ethiopia:': '🇪🇹',
#  ':European_Union:': '🇪🇺',
#  ':FREE_button:': '🆓',
#  ':Falkland_Islands:': '🇫🇰',
#  ':Faroe_Islands:': '🇫🇴',
#  ':Fiji:': '🇫🇯',
#  ':Finland:': '🇫🇮',
#  ':France:': '🇫🇷',
#  ':French_Guiana:': '🇬🇫',
#  ':French_Polynesia:': '🇵🇫',
#  ':French_Southern_Territories:': '🇹🇫',
#  ':Gabon:': '🇬🇦',
#  ':Gambia:': '🇬🇲',
#  ':Gemini:': '♊',
#  ':Georgia:': '🇬🇪',
#  ':Germany:': '🇩🇪',
#  ':Ghana:': '🇬🇭',
#  ':Gibraltar:': '🇬🇮',
#  ':Greece:': '🇬🇷',
#  ':Greenland:': '🇬🇱',
#  ':Grenada:': '🇬🇩',
#  ':Guadeloupe:': '🇬🇵',
#  ':Guam:': '🇬🇺',
#  ':Guatemala:': '🇬🇹',
#  ':Guernsey:': '🇬🇬',
#  ':Guinea-Bissau:': '🇬🇼',
#  ':Guinea:': '🇬🇳',
#  ':Guyana:': '🇬🇾',
#  ':Haiti:': '🇭🇹',
#  ':Heard_&_McDonald_Islands:': '🇭🇲',
#  ':Honduras:': '🇭🇳',
#  ':Hong_Kong_SAR_China:': '🇭🇰',
#  ':Hungary:': '🇭🇺',
#  ':ID_button:': '🆔',
#  ':Iceland:': '🇮🇸',
#  ':India:': '🇮🇳',
#  ':Indonesia:': '🇮🇩',
#  ':Iran:': '🇮🇷',
#  ':Iraq:': '🇮🇶',
#  ':Ireland:': '🇮🇪',
#  ':Isle_of_Man:': '🇮🇲',
#  ':Israel:': '🇮🇱',
#  ':Italy:': '🇮🇹',
#  ':Jamaica:': '🇯🇲',
#  ':Japan:': '🇯🇵',
#  ':Japanese_acceptable_button:': '🉑',
#  ':Japanese_application_button:': '🈸',
#  ':Japanese_bargain_button:': '🉐',
#  ':Japanese_castle:': '🏯',
#  ':Japanese_congratulations_button:': '㊗',
#  ':Japanese_discount_button:': '🈹',
#  ':Japanese_dolls:': '🎎',
#  ':Japanese_free_of_charge_button:': '🈚',
#  ':Japanese_here_button:': '🈁',
#  ':Japanese_monthly_amount_button:': '🈷',
#  ':Japanese_no_vacancy_button:': '🈵',
#  ':Japanese_not_free_of_charge_button:': '🈶',
#  ':Japanese_open_for_business_button:': '🈺',
#  ':Japanese_passing_grade_button:': '🈴',
#  ':Japanese_post_office:': '🏣',
#  ':Japanese_prohibited_button:': '🈲',
#  ':Japanese_reserved_button:': '🈯',
#  ':Japanese_secret_button:': '㊙',
#  ':Japanese_service_charge_button:': '🈂',
#  ':Japanese_symbol_for_beginner:': '🔰',
#  ':Japanese_vacancy_button:': '🈳',
#  ':Japanese_congratulations_button_selector:': '㊗️',
#  ':Japanese_monthly_amount_button_selector:': '🈷️',
#  ':Japanese_secret_button_selector:': '㊙️',
#  ':Japanese_service_charge_button_selector:': '🈂️',
#  ':Jersey:': '🇯🇪',
#  ':Jordan:': '🇯🇴',
#  ':Kazakhstan:': '🇰🇿',
#  ':Kenya:': '🇰🇪',
#  ':Kiribati:': '🇰🇮',
#  ':Kosovo:': '🇽🇰',
#  ':Kuwait:': '🇰🇼',
#  ':Kyrgyzstan:': '🇰🇬',
#  ':Laos:': '🇱🇦',
#  ':Latvia:': '🇱🇻',
#  ':Lebanon:': '🇱🇧',
#  ':Leo:': '♌',
#  ':Lesotho:': '🇱🇸',
#  ':Liberia:': '🇱🇷',
#  ':Libra:': '♎',
#  ':Libya:': '🇱🇾',
#  ':Liechtenstein:': '🇱🇮',
#  ':Lithuania:': '🇱🇹',
#  ':Luxembourg:': '🇱🇺',
#  ':Macau_SAR_China:': '🇲🇴',
#  ':Macedonia:': '🇲🇰',
#  ':Madagascar:': '🇲🇬',
#  ':Malawi:': '🇲🇼',
#  ':Malaysia:': '🇲🇾',
#  ':Maldives:': '🇲🇻',
#  ':Mali:': '🇲🇱',
#  ':Malta:': '🇲🇹',
#  ':Marshall_Islands:': '🇲🇭',
#  ':Martinique:': '🇲🇶',
#  ':Mauritania:': '🇲🇷',
#  ':Mauritius:': '🇲🇺',
#  ':Mayotte:': '🇾🇹',
#  ':Mexico:': '🇲🇽',
#  ':Micronesia:': '🇫🇲',
#  ':Moldova:': '🇲🇩',
#  ':Monaco:': '🇲🇨',
#  ':Mongolia:': '🇲🇳',
#  ':Montenegro:': '🇲🇪',
#  ':Montserrat:': '🇲🇸',
#  ':Morocco:': '🇲🇦',
#  ':Mozambique:': '🇲🇿',
#  ':Mrs._Claus:': '🤶',
#  ':Mrs._Claus_dark_skin_tone:': '🤶🏿',
#  ':Mrs._Claus_light_skin_tone:': '🤶🏻',
#  ':Mrs._Claus_medium-dark_skin_tone:': '🤶🏾',
#  ':Mrs._Claus_medium-light_skin_tone:': '🤶🏼',
#  ':Mrs._Claus_medium_skin_tone:': '🤶🏽',
#  ':Myanmar_(Burma):': '🇲🇲',
#  ':NEW_button:': '🆕',
#  ':NG_button:': '🆖',
#  ':Namibia:': '🇳🇦',
#  ':Nauru:': '🇳🇷',
#  ':Nepal:': '🇳🇵',
#  ':Netherlands:': '🇳🇱',
#  ':New_Caledonia:': '🇳🇨',
#  ':New_Zealand:': '🇳🇿',
#  ':Nicaragua:': '🇳🇮',
#  ':Niger:': '🇳🇪',
#  ':Nigeria:': '🇳🇬',
#  ':Niue:': '🇳🇺',
#  ':Norfolk_Island:': '🇳🇫',
#  ':North_Korea:': '🇰🇵',
#  ':Northern_Mariana_Islands:': '🇲🇵',
#  ':Norway:': '🇳🇴',
#  ':OK_button:': '🆗',
#  ':OK_hand:': '👌',
#  ':OK_hand_dark_skin_tone:': '👌🏿',
#  ':OK_hand_light_skin_tone:': '👌🏻',
#  ':OK_hand_medium-dark_skin_tone:': '👌🏾',
#  ':OK_hand_medium-light_skin_tone:': '👌🏼',
#  ':OK_hand_medium_skin_tone:': '👌🏽',
#  ':ON!_arrow:': '🔛',
#  ':O_button_(blood_type):': '🅾',
#  ':O_button_(blood_type)_selector:': '🅾️',
#  ':Oman:': '🇴🇲',
#  ':Ophiuchus:': '⛎',
#  ':P_button:': '🅿',
#  ':P_button_selector:': '🅿️',
#  ':Pakistan:': '🇵🇰',
#  ':Palau:': '🇵🇼',
#  ':Palestinian_Territories:': '🇵🇸',
#  ':Panama:': '🇵🇦',
#  ':Papua_New_Guinea:': '🇵🇬',
#  ':Paraguay:': '🇵🇾',
#  ':Peru:': '🇵🇪',
#  ':Philippines:': '🇵🇭',
#  ':Pisces:': '♓',
#  ':Pitcairn_Islands:': '🇵🇳',
#  ':Poland:': '🇵🇱',
#  ':Portugal:': '🇵🇹',
#  ':Puerto_Rico:': '🇵🇷',
#  ':Qatar:': '🇶🇦',
#  ':Romania:': '🇷🇴',
#  ':Russia:': '🇷🇺',
#  ':Rwanda:': '🇷🇼',
#  ':Réunion:': '🇷🇪',
#  ':SOON_arrow:': '🔜',
#  ':SOS_button:': '🆘',
#  ':Sagittarius:': '♐',
#  ':Samoa:': '🇼🇸',
#  ':San_Marino:': '🇸🇲',
#  ':Santa_Claus:': '🎅',
#  ':Santa_Claus_dark_skin_tone:': '🎅🏿',
#  ':Santa_Claus_light_skin_tone:': '🎅🏻',
#  ':Santa_Claus_medium-dark_skin_tone:': '🎅🏾',
#  ':Santa_Claus_medium-light_skin_tone:': '🎅🏼',
#  ':Santa_Claus_medium_skin_tone:': '🎅🏽',
#  ':Saudi_Arabia:': '🇸🇦',
#  ':Scorpio:': '♏',
#  ':Scotland:': '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#  ':Senegal:': '🇸🇳',
#  ':Serbia:': '🇷🇸',
#  ':Seychelles:': '🇸🇨',
#  ':Sierra_Leone:': '🇸🇱',
#  ':Singapore:': '🇸🇬',
#  ':Sint_Maarten:': '🇸🇽',
#  ':Slovakia:': '🇸🇰',
#  ':Slovenia:': '🇸🇮',
#  ':Solomon_Islands:': '🇸🇧',
#  ':Somalia:': '🇸🇴',
#  ':South_Africa:': '🇿🇦',
#  ':South_Georgia_&_South_Sandwich_Islands:': '🇬🇸',
#  ':South_Korea:': '🇰🇷',
#  ':South_Sudan:': '🇸🇸',
#  ':Spain:': '🇪🇸',
#  ':Sri_Lanka:': '🇱🇰',
#  ':St._Barthélemy:': '🇧🇱',
#  ':St._Helena:': '🇸🇭',
#  ':St._Kitts_&_Nevis:': '🇰🇳',
#  ':St._Lucia:': '🇱🇨',
#  ':St._Martin:': '🇲🇫',
#  ':St._Pierre_&_Miquelon:': '🇵🇲',
#  ':St._Vincent_&_Grenadines:': '🇻🇨',
#  ':Statue_of_Liberty:': '🗽',
#  ':Sudan:': '🇸🇩',
#  ':Suriname:': '🇸🇷',
#  ':Svalbard_&_Jan_Mayen:': '🇸🇯',
#  ':Swaziland:': '🇸🇿',
#  ':Sweden:': '🇸🇪',
#  ':Switzerland:': '🇨🇭',
#  ':Syria:': '🇸🇾',
#  ':São_Tomé_&_Príncipe:': '🇸🇹',
#  ':T-Rex:': '🦖',
#  ':TOP_arrow:': '🔝',
#  ':Taiwan:': '🇹🇼',
#  ':Tajikistan:': '🇹🇯',
#  ':Tanzania:': '🇹🇿',
#  ':Taurus:': '♉',
#  ':Thailand:': '🇹🇭',
#  ':Timor-Leste:': '🇹🇱',
#  ':Togo:': '🇹🇬',
#  ':Tokelau:': '🇹🇰',
#  ':Tokyo_tower:': '🗼',
#  ':Tonga:': '🇹🇴',
#  ':Trinidad_&_Tobago:': '🇹🇹',
#  ':Tristan_da_Cunha:': '🇹🇦',
#  ':Tunisia:': '🇹🇳',
#  ':Turkey:': '🇹🇷',
#  ':Turkmenistan:': '🇹🇲',
#  ':Turks_&_Caicos_Islands:': '🇹🇨',
#  ':Tuvalu:': '🇹🇻',
#  ':U.S._Outlying_Islands:': '🇺🇲',
#  ':U.S._Virgin_Islands:': '🇻🇮',
#  ':UP!_button:': '🆙',
#  ':Uganda:': '🇺🇬',
#  ':Ukraine:': '🇺🇦',
#  ':United_Arab_Emirates:': '🇦🇪',
#  ':United_Kingdom:': '🇬🇧',
#  ':United_Nations:': '🇺🇳',
#  ':United_States:': '🇺🇸',
#  ':Uruguay:': '🇺🇾',
#  ':Uzbekistan:': '🇺🇿',
#  ':VS_button:': '🆚',
#  ':Vanuatu:': '🇻🇺',
#  ':Vatican_City:': '🇻🇦',
#  ':Venezuela:': '🇻🇪',
#  ':Vietnam:': '🇻🇳',
#  ':Virgo:': '♍',
#  ':Wales:': '🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#  ':Wallis_&_Futuna:': '🇼🇫',
#  ':Western_Sahara:': '🇪🇭',
#  ':Yemen:': '🇾🇪',
#  ':Zambia:': '🇿🇲',
#  ':Zimbabwe:': '🇿🇼',
#  ':abacus:': '🧮',
#  ':adhesive_bandage:': '\U0001fa79',
#  ':admission_tickets:': '🎟',
#  ':admission_tickets_selector:': '🎟️',
#  ':adult:': '🧑',
#  ':adult_dark_skin_tone:': '🧑🏿',
#  ':adult_light_skin_tone:': '🧑🏻',
#  ':adult_medium-dark_skin_tone:': '🧑🏾',
#  ':adult_medium-light_skin_tone:': '🧑🏼',
#  ':adult_medium_skin_tone:': '🧑🏽',
#  ':aerial_tramway:': '🚡',
#  ':airplane:': '✈',
#  ':airplane_arrival:': '🛬',
#  ':airplane_departure:': '🛫',
#  ':airplane_selector:': '✈️',
#  ':alarm_clock:': '⏰',
#  ':alembic:': '⚗',
#  ':alembic_selector:': '⚗️',
#  ':alien:': '👽',
#  ':alien_monster:': '👾',
#  ':ambulance:': '🚑',
#  ':american_football:': '🏈',
#  ':amphora:': '🏺',
#  ':anchor:': '⚓',
#  ':anger_symbol:': '💢',
#  ':angry_face:': '😠',
#  ':angry_face_with_horns:': '👿',
#  ':anguished_face:': '😧',
#  ':ant:': '🐜',
#  ':antenna_bars:': '📶',
#  ':anxious_face_with_sweat:': '😰',
#  ':articulated_lorry:': '🚛',
#  ':artist_palette:': '🎨',
#  ':astonished_face:': '😲',
#  ':atom_symbol:': '⚛',
#  ':atom_symbol_selector:': '⚛️',
#  ':auto_rickshaw:': '\U0001f6fa',
#  ':automobile:': '🚗',
#  ':avocado:': '🥑',
#  ':axe:': '\U0001fa93',
#  ':baby:': '👶',
#  ':baby_angel:': '👼',
#  ':baby_angel_dark_skin_tone:': '👼🏿',
#  ':baby_angel_light_skin_tone:': '👼🏻',
#  ':baby_angel_medium-dark_skin_tone:': '👼🏾',
#  ':baby_angel_medium-light_skin_tone:': '👼🏼',
#  ':baby_angel_medium_skin_tone:': '👼🏽',
#  ':baby_bottle:': '🍼',
#  ':baby_chick:': '🐤',
#  ':baby_dark_skin_tone:': '👶🏿',
#  ':baby_light_skin_tone:': '👶🏻',
#  ':baby_medium-dark_skin_tone:': '👶🏾',
#  ':baby_medium-light_skin_tone:': '👶🏼',
#  ':baby_medium_skin_tone:': '👶🏽',
#  ':baby_symbol:': '🚼',
#  ':backhand_index_pointing_down:': '👇',
#  ':backhand_index_pointing_down_dark_skin_tone:': '👇🏿',
#  ':backhand_index_pointing_down_light_skin_tone:': '👇🏻',
#  ':backhand_index_pointing_down_medium-dark_skin_tone:': '👇🏾',
#  ':backhand_index_pointing_down_medium-light_skin_tone:': '👇🏼',
#  ':backhand_index_pointing_down_medium_skin_tone:': '👇🏽',
#  ':backhand_index_pointing_left:': '👈',
#  ':backhand_index_pointing_left_dark_skin_tone:': '👈🏿',
#  ':backhand_index_pointing_left_light_skin_tone:': '👈🏻',
#  ':backhand_index_pointing_left_medium-dark_skin_tone:': '👈🏾',
#  ':backhand_index_pointing_left_medium-light_skin_tone:': '👈🏼',
#  ':backhand_index_pointing_left_medium_skin_tone:': '👈🏽',
#  ':backhand_index_pointing_right:': '👉',
#  ':backhand_index_pointing_right_dark_skin_tone:': '👉🏿',
#  ':backhand_index_pointing_right_light_skin_tone:': '👉🏻',
#  ':backhand_index_pointing_right_medium-dark_skin_tone:': '👉🏾',
#  ':backhand_index_pointing_right_medium-light_skin_tone:': '👉🏼',
#  ':backhand_index_pointing_right_medium_skin_tone:': '👉🏽',
#  ':backhand_index_pointing_up:': '👆',
#  ':backhand_index_pointing_up_dark_skin_tone:': '👆🏿',
#  ':backhand_index_pointing_up_light_skin_tone:': '👆🏻',
#  ':backhand_index_pointing_up_medium-dark_skin_tone:': '👆🏾',
#  ':backhand_index_pointing_up_medium-light_skin_tone:': '👆🏼',
#  ':backhand_index_pointing_up_medium_skin_tone:': '👆🏽',
#  ':bacon:': '🥓',
#  ':badger:': '🦡',
#  ':badminton:': '🏸',
#  ':bagel:': '🥯',
#  ':baggage_claim:': '🛄',
#  ':baguette_bread:': '🥖',
#  ':balance_scale:': '⚖',
#  ':balance_scale_selector:': '⚖️',
#  ':bald:': '🦲',
#  ':bald_man:': '👨\u200d🦲',
#  ':bald_woman:': '👩\u200d🦲',
#  ':ballet_shoes:': '\U0001fa70',
#  ':balloon:': '🎈',
#  ':ballot_box_with_ballot:': '🗳',
#  ':ballot_box_with_ballot_selector:': '🗳️',
#  ':ballot_box_with_check:': '☑',
#  ':banana:': '🍌',
#  ':banjo:': '\U0001fa95',
#  ':bank:': '🏦',
#  ':bar_chart:': '📊',
#  ':barber_pole:': '💈',
#  ':baseball:': '⚾',
#  ':basket:': '🧺',
#  ':basketball:': '🏀',
#  ':bat:': '🦇',
#  ':bathtub:': '🛁',
#  ':battery:': '🔋',
#  ':beach_with_umbrella:': '🏖',
#  ':beach_with_umbrella_selector:': '🏖️',
#  ':beaming_face_with_smiling_eyes:': '😁',
#  ':bear_face:': '🐻',
#  ':bearded_person:': '🧔',
#  ':bearded_person_dark_skin_tone:': '🧔🏿',
#  ':bearded_person_light_skin_tone:': '🧔🏻',
#  ':bearded_person_medium-dark_skin_tone:': '🧔🏾',
#  ':bearded_person_medium-light_skin_tone:': '🧔🏼',
#  ':bearded_person_medium_skin_tone:': '🧔🏽',
#  ':beating_heart:': '💓',
#  ':bed:': '🛏',
#  ':bed_selector:': '🛏️',
#  ':beer_mug:': '🍺',
#  ':bell:': '🔔',
#  ':bell_with_slash:': '🔕',
#  ':bellhop_bell:': '🛎',
#  ':bellhop_bell_selector:': '🛎️',
#  ':bento_box:': '🍱',
#  ':beverage_box:': '\U0001f9c3',
#  ':bicycle:': '🚲',
#  ':bikini:': '👙',
#  ':billed_cap:': '🧢',
#  ':biohazard:': '☣',
#  ':biohazard_selector:': '☣️',
#  ':bird:': '🐦',
#  ':birthday_cake:': '🎂',
#  ':black_circle:': '⚫',
#  ':black_flag:': '🏴',
#  ':black_heart:': '🖤',
#  ':black_large_square:': '⬛',
#  ':black_medium-small_square:': '◾',
#  ':black_medium_square:': '◼',
#  ':black_medium_square_selector:': '◼️',
#  ':black_nib:': '✒',
#  ':black_nib_selector:': '✒️',
#  ':black_small_square:': '▪',
#  ':black_small_square_selector:': '▪️',
#  ':black_square_button:': '🔲',
#  ':blond-haired_man:': '👱\u200d♂️',
#  ':blond-haired_man_dark_skin_tone:': '👱🏿\u200d♂️',
#  ':blond-haired_man_light_skin_tone:': '👱🏻\u200d♂️',
#  ':blond-haired_man_medium-dark_skin_tone:': '👱🏾\u200d♂️',
#  ':blond-haired_man_medium-light_skin_tone:': '👱🏼\u200d♂️',
#  ':blond-haired_man_medium_skin_tone:': '👱🏽\u200d♂️',
#  ':blond-haired_person:': '👱',
#  ':blond-haired_person_dark_skin_tone:': '👱🏿',
#  ':blond-haired_person_light_skin_tone:': '👱🏻',
#  ':blond-haired_person_medium-dark_skin_tone:': '👱🏾',
#  ':blond-haired_person_medium-light_skin_tone:': '👱🏼',
#  ':blond-haired_person_medium_skin_tone:': '👱🏽',
#  ':blond-haired_woman:': '👱\u200d♀️',
#  ':blond-haired_woman_dark_skin_tone:': '👱🏿\u200d♀️',
#  ':blond-haired_woman_light_skin_tone:': '👱🏻\u200d♀️',
#  ':blond-haired_woman_medium-dark_skin_tone:': '👱🏾\u200d♀️',
#  ':blond-haired_woman_medium-light_skin_tone:': '👱🏼\u200d♀️',
#  ':blond-haired_woman_medium_skin_tone:': '👱🏽\u200d♀️',
#  ':blossom:': '🌼',
#  ':blowfish:': '🐡',
#  ':blue_book:': '📘',
#  ':blue_circle:': '🔵',
#  ':blue_heart:': '💙',
#  ':blue_square:': '\U0001f7e6',
#  ':boar:': '🐗',
#  ':bomb:': '💣',
#  ':bone:': '🦴',
#  ':bookmark:': '🔖',
#  ':bookmark_tabs:': '📑',
#  ':books:': '📚',
#  ':bottle_with_popping_cork:': '🍾',
#  ':bouquet:': '💐',
#  ':bow_and_arrow:': '🏹',
#  ':bowl_with_spoon:': '🥣',
#  ':bowling:': '🎳',
#  ':boxing_glove:': '🥊',
#  ':boy:': '👦',
#  ':boy_dark_skin_tone:': '👦🏿',
#  ':boy_light_skin_tone:': '👦🏻',
#  ':boy_medium-dark_skin_tone:': '👦🏾',
#  ':boy_medium-light_skin_tone:': '👦🏼',
#  ':boy_medium_skin_tone:': '👦🏽',
#  ':brain:': '🧠',
#  ':bread:': '🍞',
#  ':breast-feeding:': '🤱',
#  ':breast-feeding_dark_skin_tone:': '🤱🏿',
#  ':breast-feeding_light_skin_tone:': '🤱🏻',
#  ':breast-feeding_medium-dark_skin_tone:': '🤱🏾',
#  ':breast-feeding_medium-light_skin_tone:': '🤱🏼',
#  ':breast-feeding_medium_skin_tone:': '🤱🏽',
#  ':brick:': '🧱',
#  ':bride_with_veil:': '👰',
#  ':bride_with_veil_dark_skin_tone:': '👰🏿',
#  ':bride_with_veil_light_skin_tone:': '👰🏻',
#  ':bride_with_veil_medium-dark_skin_tone:': '👰🏾',
#  ':bride_with_veil_medium-light_skin_tone:': '👰🏼',
#  ':bride_with_veil_medium_skin_tone:': '👰🏽',
#  ':bridge_at_night:': '🌉',
#  ':briefcase:': '💼',
#  ':briefs:': '\U0001fa72',
#  ':bright_button:': '🔆',
#  ':broccoli:': '🥦',
#  ':broken_heart:': '💔',
#  ':broom:': '🧹',
#  ':brown_circle:': '\U0001f7e4',
#  ':brown_heart:': '\U0001f90e',
#  ':brown_square:': '\U0001f7eb',
#  ':bug:': '🐛',
#  ':building_construction:': '🏗',
#  ':building_construction_selector:': '🏗️',
#  ':bullet_train:': '🚅',
#  ':burrito:': '🌯',
#  ':bus:': '🚌',
#  ':bus_stop:': '🚏',
#  ':bust_in_silhouette:': '👤',
#  ':busts_in_silhouette:': '👥',
#  ':butter:': '\U0001f9c8',
#  ':butterfly:': '🦋',
#  ':cactus:': '🌵',
#  ':calendar:': '📅',
#  ':call_me_hand:': '🤙',
#  ':call_me_hand_dark_skin_tone:': '🤙🏿',
#  ':call_me_hand_light_skin_tone:': '🤙🏻',
#  ':call_me_hand_medium-dark_skin_tone:': '🤙🏾',
#  ':call_me_hand_medium-light_skin_tone:': '🤙🏼',
#  ':call_me_hand_medium_skin_tone:': '🤙🏽',
#  ':camel:': '🐪',
#  ':camera:': '📷',
#  ':camera_with_flash:': '📸',
#  ':camping:': '🏕',
#  ':camping_selector:': '🏕️',
#  ':candle:': '🕯',
#  ':candle_selector:': '🕯️',
#  ':candy:': '🍬',
#  ':canned_food:': '🥫',
#  ':canoe:': '🛶',
#  ':card_file_box:': '🗃',
#  ':card_file_box_selector:': '🗃️',
#  ':card_index:': '📇',
#  ':card_index_dividers:': '🗂',
#  ':card_index_dividers_selector:': '🗂️',
#  ':carousel_horse:': '🎠',
#  ':carp_streamer:': '🎏',
#  ':carrot:': '🥕',
#  ':castle:': '🏰',
#  ':cat:': '🐈',
#  ':cat_face:': '🐱',
#  ':cat_face_with_tears_of_joy:': '😹',
#  ':cat_face_with_wry_smile:': '😼',
#  ':chains:': '⛓',
#  ':chains_selector:': '⛓️',
#  ':chair:': '\U0001fa91',
#  ':chart_decreasing:': '📉',
#  ':chart_increasing:': '📈',
#  ':chart_increasing_with_yen:': '💹',
#  ':check_box_with_check:': '☑️',
#  ':check_mark:': '✔️',
#  ':cheese_wedge:': '🧀',
#  ':chequered_flag:': '🏁',
#  ':cherries:': '🍒',
#  ':cherry_blossom:': '🌸',
#  ':chess_pawn:': '♟',
#  ':chess_pawn_selector:': '♟️',
#  ':chestnut:': '🌰',
#  ':chicken:': '🐔',
#  ':child:': '🧒',
#  ':child_dark_skin_tone:': '🧒🏿',
#  ':child_light_skin_tone:': '🧒🏻',
#  ':child_medium-dark_skin_tone:': '🧒🏾',
#  ':child_medium-light_skin_tone:': '🧒🏼',
#  ':child_medium_skin_tone:': '🧒🏽',
#  ':children_crossing:': '🚸',
#  ':chipmunk:': '🐿',
#  ':chipmunk_selector:': '🐿️',
#  ':chocolate_bar:': '🍫',
#  ':chopsticks:': '🥢',
#  ':church:': '⛪',
#  ':cigarette:': '🚬',
#  ':cinema:': '🎦',
#  ':circled_M:': 'Ⓜ',
#  ':circled_M_selector:': 'Ⓜ️',
#  ':circus_tent:': '🎪',
#  ':cityscape:': '🏙',
#  ':cityscape_at_dusk:': '🌆',
#  ':cityscape_selector:': '🏙️',
#  ':clamp:': '🗜',
#  ':clamp_selector:': '🗜️',
#  ':clapper_board:': '🎬',
#  ':clapping_hands:': '👏',
#  ':clapping_hands_dark_skin_tone:': '👏🏿',
#  ':clapping_hands_light_skin_tone:': '👏🏻',
#  ':clapping_hands_medium-dark_skin_tone:': '👏🏾',
#  ':clapping_hands_medium-light_skin_tone:': '👏🏼',
#  ':clapping_hands_medium_skin_tone:': '👏🏽',
#  ':classical_building:': '🏛',
#  ':classical_building_selector:': '🏛️',
#  ':clinking_beer_mugs:': '🍻',
#  ':clinking_glasses:': '🥂',
#  ':clipboard:': '📋',
#  ':clockwise_vertical_arrows:': '🔃',
#  ':closed_book:': '📕',
#  ':closed_mailbox_with_lowered_flag:': '📪',
#  ':closed_mailbox_with_raised_flag:': '📫',
#  ':closed_umbrella:': '🌂',
#  ':cloud:': '☁',
#  ':cloud_selector:': '☁️',
#  ':cloud_with_lightning:': '🌩',
#  ':cloud_with_lightning_and_rain:': '⛈',
#  ':cloud_with_lightning_and_rain_selector:': '⛈️',
#  ':cloud_with_lightning_selector:': '🌩️',
#  ':cloud_with_rain:': '🌧',
#  ':cloud_with_rain_selector:': '🌧️',
#  ':cloud_with_snow:': '🌨',
#  ':cloud_with_snow_selector:': '🌨️',
#  ':clown_face:': '🤡',
#  ':club_suit:': '♣',
#  ':club_suit_selector:': '♣️',
#  ':clutch_bag:': '👝',
#  ':coat:': '🧥',
#  ':cocktail_glass:': '🍸',
#  ':coconut:': '🥥',
#  ':coffin:': '⚰',
#  ':coffin_selector:': '⚰️',
#  ':cold_face:': '🥶',
#  ':collision:': '💥',
#  ':comet:': '☄',
#  ':comet_selector:': '☄️',
#  ':compass:': '🧭',
#  ':computer_disk:': '💽',
#  ':computer_mouse:': '🖱',
#  ':computer_mouse_selector:': '🖱️',
#  ':confetti_ball:': '🎊',
#  ':confounded_face:': '😖',
#  ':confused_face:': '😕',
#  ':construction:': '🚧',
#  ':construction_worker:': '👷',
#  ':construction_worker_dark_skin_tone:': '👷🏿',
#  ':construction_worker_light_skin_tone:': '👷🏻',
#  ':construction_worker_medium-dark_skin_tone:': '👷🏾',
#  ':construction_worker_medium-light_skin_tone:': '👷🏼',
#  ':construction_worker_medium_skin_tone:': '👷🏽',
#  ':control_knobs:': '🎛',
#  ':control_knobs_selector:': '🎛️',
#  ':convenience_store:': '🏪',
#  ':cooked_rice:': '🍚',
#  ':cookie:': '🍪',
#  ':cooking:': '🍳',
#  ':copyright:': '©',
#  ':copyright_selector:': '©️',
#  ':couch_and_lamp:': '🛋',
#  ':couch_and_lamp_selector:': '🛋️',
#  ':counterclockwise_arrows_button:': '🔄',
#  ':couple_with_heart-man-man:': '👨\u200d❤\u200d👨',
#  ':couple_with_heart-woman-man:': '👩\u200d❤\u200d👨',
#  ':couple_with_heart-woman-woman:': '👩\u200d❤\u200d👩',
#  ':couple_with_heart:': '💑',
#  ':couple_with_heart_man_man:': '👨\u200d❤️\u200d👨',
#  ':couple_with_heart_woman_man:': '👩\u200d❤️\u200d👨',
#  ':couple_with_heart_woman_woman:': '👩\u200d❤️\u200d👩',
#  ':cow:': '🐄',
#  ':cow_face:': '🐮',
#  ':cowboy_hat_face:': '🤠',
#  ':crab:': '🦀',
#  ':crayon:': '🖍',
#  ':crayon_selector:': '🖍️',
#  ':credit_card:': '💳',
#  ':crescent_moon:': '🌙',
#  ':cricket:': '🦗',
#  ':cricket_game:': '🏏',
#  ':crocodile:': '🐊',
#  ':croissant:': '🥐',
#  ':cross_mark:': '❌',
#  ':cross_mark_button:': '❎',
#  ':crossed_fingers:': '🤞',
#  ':crossed_fingers_dark_skin_tone:': '🤞🏿',
#  ':crossed_fingers_light_skin_tone:': '🤞🏻',
#  ':crossed_fingers_medium-dark_skin_tone:': '🤞🏾',
#  ':crossed_fingers_medium-light_skin_tone:': '🤞🏼',
#  ':crossed_fingers_medium_skin_tone:': '🤞🏽',
#  ':crossed_flags:': '🎌',
#  ':crossed_swords:': '⚔',
#  ':crossed_swords_selector:': '⚔️',
#  ':crown:': '👑',
#  ':crying_cat_face:': '😿',
#  ':crying_face:': '😢',
#  ':crystal_ball:': '🔮',
#  ':cucumber:': '🥒',
#  ':cup_with_straw:': '🥤',
#  ':cupcake:': '🧁',
#  ':curling_stone:': '🥌',
#  ':curly-haired_man:': '👨\u200d🦱',
#  ':curly-haired_woman:': '👩\u200d🦱',
#  ':curly_hair:': '🦱',
#  ':curly_loop:': '➰',
#  ':currency_exchange:': '💱',
#  ':curry_rice:': '🍛',
#  ':custard:': '🍮',
#  ':customs:': '🛃',
#  ':cut_of_meat:': '🥩',
#  ':cyclone:': '🌀',
#  ':dagger:': '🗡',
#  ':dagger_selector:': '🗡️',
#  ':dango:': '🍡',
#  ':dark_skin_tone:': '🏿',
#  ':dashing_away:': '💨',
#  ':deaf_man-dark_skin_tone:': '\U0001f9cf🏿\u200d♂',
#  ':deaf_man-dark_skin_tone_selector:': '\U0001f9cf🏿\u200d♂️',
#  ':deaf_man-light_skin_tone:': '\U0001f9cf🏻\u200d♂',
#  ':deaf_man-light_skin_tone_selector:': '\U0001f9cf🏻\u200d♂️',
#  ':deaf_man-medium-dark_skin_tone:': '\U0001f9cf🏾\u200d♂',
#  ':deaf_man-medium-dark_skin_tone_selector:': '\U0001f9cf🏾\u200d♂️',
#  ':deaf_man-medium-light_skin_tone:': '\U0001f9cf🏼\u200d♂',
#  ':deaf_man-medium-light_skin_tone_selector:': '\U0001f9cf🏼\u200d♂️',
#  ':deaf_man-medium_skin_tone:': '\U0001f9cf🏽\u200d♂',
#  ':deaf_man-medium_skin_tone_selector:': '\U0001f9cf🏽\u200d♂️',
#  ':deaf_man:': '\U0001f9cf\u200d♂',
#  ':deaf_man_selector:': '\U0001f9cf\u200d♂️',
#  ':deaf_person-dark_skin_tone:': '\U0001f9cf🏿',
#  ':deaf_person-light_skin_tone:': '\U0001f9cf🏻',
#  ':deaf_person-medium-dark_skin_tone:': '\U0001f9cf🏾',
#  ':deaf_person-medium-light_skin_tone:': '\U0001f9cf🏼',
#  ':deaf_person-medium_skin_tone:': '\U0001f9cf🏽',
#  ':deaf_person:': '\U0001f9cf',
#  ':deaf_woman-dark_skin_tone:': '\U0001f9cf🏿\u200d♀',
#  ':deaf_woman-dark_skin_tone_selector:': '\U0001f9cf🏿\u200d♀️',
#  ':deaf_woman-light_skin_tone:': '\U0001f9cf🏻\u200d♀',
#  ':deaf_woman-light_skin_tone_selector:': '\U0001f9cf🏻\u200d♀️',
#  ':deaf_woman-medium-dark_skin_tone:': '\U0001f9cf🏾\u200d♀',
#  ':deaf_woman-medium-dark_skin_tone_selector:': '\U0001f9cf🏾\u200d♀️',
#  ':deaf_woman-medium-light_skin_tone:': '\U0001f9cf🏼\u200d♀',
#  ':deaf_woman-medium-light_skin_tone_selector:': '\U0001f9cf🏼\u200d♀️',
#  ':deaf_woman-medium_skin_tone:': '\U0001f9cf🏽\u200d♀',
#  ':deaf_woman-medium_skin_tone_selector:': '\U0001f9cf🏽\u200d♀️',
#  ':deaf_woman:': '\U0001f9cf\u200d♀',
#  ':deaf_woman_selector:': '\U0001f9cf\u200d♀️',
#  ':deciduous_tree:': '🌳',
#  ':deer:': '🦌',
#  ':delivery_truck:': '🚚',
#  ':department_store:': '🏬',
#  ':derelict_house:': '🏚',
#  ':derelict_house_selector:': '🏚️',
#  ':desert:': '🏜',
#  ':desert_island:': '🏝',
#  ':desert_island_selector:': '🏝️',
#  ':desert_selector:': '🏜️',
#  ':desktop_computer:': '🖥',
#  ':desktop_computer_selector:': '🖥️',
#  ':detective:': '🕵',
#  ':detective_dark_skin_tone:': '🕵🏿',
#  ':detective_light_skin_tone:': '🕵🏻',
#  ':detective_medium-dark_skin_tone:': '🕵🏾',
#  ':detective_medium-light_skin_tone:': '🕵🏼',
#  ':detective_medium_skin_tone:': '🕵🏽',
#  ':detective_selector:': '🕵️',
#  ':diamond_suit:': '♦',
#  ':diamond_suit_selector:': '♦️',
#  ':diamond_with_a_dot:': '💠',
#  ':dim_button:': '🔅',
#  ':direct_hit:': '🎯',
#  ':disappointed_face:': '😞',
#  ':diving_mask:': '\U0001f93f',
#  ':diya_lamp:': '\U0001fa94',
#  ':dizzy:': '💫',
#  ':dizzy_face:': '😵',
#  ':dna:': '🧬',
#  ':dog:': '🐕',
#  ':dog_face:': '🐶',
#  ':dollar_banknote:': '💵',
#  ':dolphin:': '🐬',
#  ':door:': '🚪',
#  ':dotted_six-pointed_star:': '🔯',
#  ':double_curly_loop:': '➿',
#  ':double_exclamation_mark:': '‼',
#  ':double_exclamation_mark_selector:': '‼️',
#  ':doughnut:': '🍩',
#  ':dove:': '🕊',
#  ':dove_selector:': '🕊️',
#  ':down-left_arrow:': '↙',
#  ':down-left_arrow_selector:': '↙️',
#  ':down-right_arrow:': '↘',
#  ':down-right_arrow_selector:': '↘️',
#  ':down_arrow:': '⬇',
#  ':down_arrow_selector:': '⬇️',
#  ':downcast_face_with_sweat:': '😓',
#  ':downwards_button:': '🔽',
#  ':dragon:': '🐉',
#  ':dragon_face:': '🐲',
#  ':dress:': '👗',
#  ':drooling_face:': '🤤',
#  ':drop_of_blood:': '\U0001fa78',
#  ':droplet:': '💧',
#  ':drum:': '🥁',
#  ':duck:': '🦆',
#  ':dumpling:': '🥟',
#  ':dvd:': '📀',
#  ':e-mail:': '📧',
#  ':eagle:': '🦅',
#  ':ear:': '👂',
#  ':ear_dark_skin_tone:': '👂🏿',
#  ':ear_light_skin_tone:': '👂🏻',
#  ':ear_medium-dark_skin_tone:': '👂🏾',
#  ':ear_medium-light_skin_tone:': '👂🏼',
#  ':ear_medium_skin_tone:': '👂🏽',
#  ':ear_of_corn:': '🌽',
#  ':ear_with_hearing_aid-dark_skin_tone:': '\U0001f9bb🏿',
#  ':ear_with_hearing_aid-light_skin_tone:': '\U0001f9bb🏻',
#  ':ear_with_hearing_aid-medium-dark_skin_tone:': '\U0001f9bb🏾',
#  ':ear_with_hearing_aid-medium-light_skin_tone:': '\U0001f9bb🏼',
#  ':ear_with_hearing_aid-medium_skin_tone:': '\U0001f9bb🏽',
#  ':ear_with_hearing_aid:': '\U0001f9bb',
#  ':egg:': '🥚',
#  ':eggplant:': '🍆',
#  ':eight-pointed_star:': '✴',
#  ':eight-pointed_star_selector:': '✴️',
#  ':eight-spoked_asterisk:': '✳',
#  ':eight-spoked_asterisk_selector:': '✳️',
#  ':eight-thirty:': '🕣',
#  ':eight_o’clock:': '🕗',
#  ':eject_button:': '⏏',
#  ':eject_button_selector:': '⏏️',
#  ':electric_plug:': '🔌',
#  ':elephant:': '🐘',
#  ':eleven-thirty:': '🕦',
#  ':eleven_o’clock:': '🕚',
#  ':elf:': '🧝',
#  ':elf_dark_skin_tone:': '🧝🏿',
#  ':elf_light_skin_tone:': '🧝🏻',
#  ':elf_medium-dark_skin_tone:': '🧝🏾',
#  ':elf_medium-light_skin_tone:': '🧝🏼',
#  ':elf_medium_skin_tone:': '🧝🏽',
#  ':envelope:': '✉',
#  ':envelope_selector:': '✉️',
#  ':envelope_with_arrow:': '📩',
#  ':euro_banknote:': '💶',
#  ':evergreen_tree:': '🌲',
#  ':ewe:': '🐑',
#  ':exclamation_mark:': '❗',
#  ':exclamation_question_mark:': '⁉',
#  ':exclamation_question_mark_selector:': '⁉️',
#  ':exploding_head:': '🤯',
#  ':expressionless_face:': '😑',
#  ':eye:': '👁',
#  ':eye_in_speech_bubble:': '👁\u200d🗨',
#  ':eye_in_speech_bubble_2:': '👁\u200d🗨️',
#  ':eye_in_speech_bubble_3:': '👁️\u200d🗨️',
#  ':eye_in_speech_bubble_selector:': '👁️\u200d🗨',
#  ':eye_selector:': '👁️',
#  ':eyes:': '👀',
#  ':face_blowing_a_kiss:': '😘',
#  ':face_savoring_food:': '😋',
#  ':face_screaming_in_fear:': '😱',
#  ':face_vomiting:': '🤮',
#  ':face_with_hand_over_mouth:': '🤭',
#  ':face_with_head-bandage:': '🤕',
#  ':face_with_medical_mask:': '😷',
#  ':face_with_monocle:': '🧐',
#  ':face_with_open_mouth:': '😮',
#  ':face_with_raised_eyebrow:': '🤨',
#  ':face_with_rolling_eyes:': '🙄',
#  ':face_with_steam_from_nose:': '😤',
#  ':face_with_symbols_on_mouth:': '🤬',
#  ':face_with_tears_of_joy:': '😂',
#  ':face_with_thermometer:': '🤒',
#  ':face_with_tongue:': '😛',
#  ':face_without_mouth:': '😶',
#  ':factory:': '🏭',
#  ':fairy:': '🧚',
#  ':fairy_dark_skin_tone:': '🧚🏿',
#  ':fairy_light_skin_tone:': '🧚🏻',
#  ':fairy_medium-dark_skin_tone:': '🧚🏾',
#  ':fairy_medium-light_skin_tone:': '🧚🏼',
#  ':fairy_medium_skin_tone:': '🧚🏽',
#  ':falafel:': '\U0001f9c6',
#  ':fallen_leaf:': '🍂',
#  ':family:': '👪',
#  ':family_man_boy:': '👨\u200d👦',
#  ':family_man_boy_boy:': '👨\u200d👦\u200d👦',
#  ':family_man_girl:': '👨\u200d👧',
#  ':family_man_girl_boy:': '👨\u200d👧\u200d👦',
#  ':family_man_girl_girl:': '👨\u200d👧\u200d👧',
#  ':family_man_man_boy:': '👨\u200d👨\u200d👦',
#  ':family_man_man_boy_boy:': '👨\u200d👨\u200d👦\u200d👦',
#  ':family_man_man_girl:': '👨\u200d👨\u200d👧',
#  ':family_man_man_girl_boy:': '👨\u200d👨\u200d👧\u200d👦',
#  ':family_man_man_girl_girl:': '👨\u200d👨\u200d👧\u200d👧',
#  ':family_man_woman_boy:': '👨\u200d👩\u200d👦',
#  ':family_man_woman_boy_boy:': '👨\u200d👩\u200d👦\u200d👦',
#  ':family_man_woman_girl:': '👨\u200d👩\u200d👧',
#  ':family_man_woman_girl_boy:': '👨\u200d👩\u200d👧\u200d👦',
#  ':family_man_woman_girl_girl:': '👨\u200d👩\u200d👧\u200d👧',
#  ':family_woman_boy:': '👩\u200d👦',
#  ':family_woman_boy_boy:': '👩\u200d👦\u200d👦',
#  ':family_woman_girl:': '👩\u200d👧',
#  ':family_woman_girl_boy:': '👩\u200d👧\u200d👦',
#  ':family_woman_girl_girl:': '👩\u200d👧\u200d👧',
#  ':family_woman_woman_boy:': '👩\u200d👩\u200d👦',
#  ':family_woman_woman_boy_boy:': '👩\u200d👩\u200d👦\u200d👦',
#  ':family_woman_woman_girl:': '👩\u200d👩\u200d👧',
#  ':family_woman_woman_girl_boy:': '👩\u200d👩\u200d👧\u200d👦',
#  ':family_woman_woman_girl_girl:': '👩\u200d👩\u200d👧\u200d👧',
#  ':fast-forward_button:': '⏩',
#  ':fast_down_button:': '⏬',
#  ':fast_reverse_button:': '⏪',
#  ':fast_up_button:': '⏫',
#  ':fax_machine:': '📠',
#  ':fearful_face:': '😨',
#  ':female_sign:': '♀',
#  ':female_sign_selector:': '♀️',
#  ':ferris_wheel:': '🎡',
#  ':ferry:': '⛴',
#  ':ferry_selector:': '⛴️',
#  ':field_hockey:': '🏑',
#  ':file_cabinet:': '🗄',
#  ':file_cabinet_selector:': '🗄️',
#  ':file_folder:': '📁',
#  ':film_frames:': '🎞',
#  ':film_frames_selector:': '🎞️',
#  ':film_projector:': '📽',
#  ':film_projector_selector:': '📽️',
#  ':fire:': '🔥',
#  ':fire_engine:': '🚒',
#  ':fire_extinguisher:': '🧯',
#  ':firecracker:': '🧨',
#  ':fireworks:': '🎆',
#  ':first_quarter_moon:': '🌓',
#  ':first_quarter_moon_face:': '🌛',
#  ':fish:': '🐟',
#  ':fish_cake_with_swirl:': '🍥',
#  ':fishing_pole:': '🎣',
#  ':five-thirty:': '🕠',
#  ':five_o’clock:': '🕔',
#  ':flag_in_hole:': '⛳',
#  ':flamingo:': '\U0001f9a9',
#  ':flashlight:': '🔦',
#  ':flat_shoe:': '🥿',
#  ':fleur-de-lis:': '⚜',
#  ':fleur-de-lis_selector:': '⚜️',
#  ':flexed_biceps:': '💪',
#  ':flexed_biceps_dark_skin_tone:': '💪🏿',
#  ':flexed_biceps_light_skin_tone:': '💪🏻',
#  ':flexed_biceps_medium-dark_skin_tone:': '💪🏾',
#  ':flexed_biceps_medium-light_skin_tone:': '💪🏼',
#  ':flexed_biceps_medium_skin_tone:': '💪🏽',
#  ':floppy_disk:': '💾',
#  ':flower_playing_cards:': '🎴',
#  ':flushed_face:': '😳',
#  ...}

# %%
emoji_dict = {0 : ":heart:", 1 : ":baseball:", 2 : ":smile:", 
              3 : ":disappointed:", 4 : ":fork_and_knife:"}

def print_emoji(label):
    
    return emoji.emojize(emoji_dict[(label)], use_aliases=True)

for i in range(5):
    print (print_emoji(i))
# Out:
# ❤
# ⚾
# 😄
# 😞
# 🍴

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('D:\Data Sets\emoji_train.csv',header=None)
test=pd.read_csv('D:\Data Sets\emoji_test.csv',header=None)

# %%
train.head()
# Out:
#                                  0  1   2     3
# 0           never talk to me again  3 NaN   NaN
# 1  I am proud of your achievements  2 NaN   NaN
# 2   It is the worst day in my life  3 NaN   NaN
# 3                 Miss you so much  0 NaN   [0]
# 4                     food is life  4 NaN   NaN

# %%
train.shape
# Out:
# (132, 4)

# %%
x_train=train[0]
y_train=train[1]

# %%
x_test=test[0]
y_test=test[1]

# %%
for i in range(5):
    print( x_train[i],emoji.emojize( emoji_dict[(y_train[i])], use_aliases=True ))
# Out:
# never talk to me again 😞
# I am proud of your achievements 😄
# It is the worst day in my life 😞
# Miss you so much ❤
# food is life 🍴

# %%
f=open('D:\Data Sets\glove.6B.50d.txt',encoding='utf-8')

# %%
embeddings_index={}

for line in f:
    values=line.split()
    word=values[0]
    coef=np.asarray(values[1:],dtype='float')
    
    embeddings_index[word]=coef
f.close()

# %%
embeddings_index["eat"]
# Out:
# array([ 6.4295e-01, -4.2946e-01, -5.4277e-01, -1.0307e+00,  1.2056e+00,
#        -2.7174e-01, -6.3561e-01, -1.5065e-02,  3.7856e-01,  4.6474e-02,
#        -1.3102e-01,  6.0500e-01,  1.6391e+00,  2.3940e-01,  1.2128e+00,
#         8.3178e-01,  7.3893e-01,  1.5200e-01, -1.4175e-01, -8.8384e-01,
#         2.0829e-02, -3.2545e-01,  1.8035e+00,  1.0045e+00,  5.8484e-01,
#        -6.2031e-01, -4.3296e-01,  2.3562e-01,  1.3027e+00, -8.1264e-01,
#         2.3158e+00,  1.1030e+00, -6.0608e-01,  1.0101e+00, -2.2426e-01,
#         1.8908e-02, -1.0931e-01,  3.8350e-01,  7.7362e-01, -8.1927e-02,
#        -3.4040e-01, -1.5143e-03, -5.6640e-02,  8.7359e-01,  1.4805e+00,
#         6.9421e-01, -3.0966e-01, -9.0826e-01,  3.7277e-03,  8.4550e-01])

# %%
def embedding_output(x):
    maxlen=10
    emb_dim=50
    embedding_out=np.zeros((x.shape[0],maxlen,emb_dim))
    
    for ix in range (x.shape[0]):
        x[ix]=x[ix].split()
        
        for ij in range(len(x[ix])):
            try:
                embedding_out[ix][ij]=embeddings_index[x[ix][ij].lower()]
            except:
                embedding_out[ix][ij]=np.zeros((50,))
                
    return embedding_out

# %%
embeddings_matrix_train=embedding_output(x_train)
embeddings_matrix_test=embedding_output(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c839c2e4993b> in <module>
# ----> 1 embeddings_matrix_train=embedding_output(x_train)
#       2 embeddings_matrix_test=embedding_output(x_test)
#
# <ipython-input-17-b51fc86496bf> in embedding_output(x)
#       5
#       6     for ix in range (x.shape[0]):
# ----> 7         x[ix]=x[ix].split()
#       8
#       9         for ij in range(len(x[ix])):
#
# AttributeError: 'list' object has no attribute 'split'

# %%
embeddings_matrix_test.shape
# Out:
# (56, 10, 50)

# %%
embeddings_matrix_train.shape
# Out:
# (132, 10, 50)

# %%
from keras.utils import to_categorical

# %%
y_train=to_categorical(y_train,num_classes=5)
y_test=to_categorical(y_test,num_classes=5)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import *

# %%
model=Sequential()
model.add(LSTM(64,input_shape=(10,50),return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 10, 64)            29440
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 10, 64)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 62,789
# Trainable params: 62,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

checkpoint=ModelCheckpoint(
    "best_emoji_model.h5",
    monitor="val_loss",
    verbose=True,
    save_best_only=True,
    save_weights_only=False,
    
)

earlystop=EarlyStopping(monitor='val_accuracy',patience=100)

hist=model.fit(embeddings_matrix_train,y_train,epochs=150,batch_size=64,shuffle=True,validation_split=0.2,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1046 - accuracy: 0.9844
# Epoch 00001: val_loss improved from inf to 1.21495, saving model to best_emoji_model.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1009 - accuracy: 0.9810 - val_loss: 1.2150 - val_accuracy: 0.7037
# Epoch 2/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0812 - accuracy: 0.9844
# Epoch 00002: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0706 - accuracy: 0.9905 - val_loss: 1.3771 - val_accuracy: 0.7037
# Epoch 3/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0489 - accuracy: 1.0000
# Epoch 00003: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0858 - accuracy: 0.9810 - val_loss: 1.4511 - val_accuracy: 0.6667
# Epoch 4/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0824 - accuracy: 0.9688
# Epoch 00004: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0822 - accuracy: 0.9714 - val_loss: 1.3789 - val_accuracy: 0.5926
# Epoch 5/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0514 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0686 - accuracy: 0.9905 - val_loss: 1.3593 - val_accuracy: 0.5926
# Epoch 6/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1228 - accuracy: 0.9531
# Epoch 00006: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0862 - accuracy: 0.9714 - val_loss: 1.5017 - val_accuracy: 0.6296
# Epoch 7/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0678 - accuracy: 0.9844
# Epoch 00007: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0691 - accuracy: 0.9905 - val_loss: 1.6060 - val_accuracy: 0.6667
# Epoch 8/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0453 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0635 - accuracy: 0.9905 - val_loss: 1.7679 - val_accuracy: 0.6296
# Epoch 9/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0667 - accuracy: 0.9844
# Epoch 00009: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0564 - accuracy: 0.9905 - val_loss: 1.8973 - val_accuracy: 0.6296
# Epoch 10/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0644 - accuracy: 0.9844
# Epoch 00010: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0501 - accuracy: 0.9905 - val_loss: 1.9432 - val_accuracy: 0.6296
# Epoch 11/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0623 - accuracy: 0.9844
# Epoch 00011: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0576 - accuracy: 0.9905 - val_loss: 1.8271 - val_accuracy: 0.5926
# Epoch 12/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0621 - accuracy: 0.9844
# Epoch 00012: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0620 - accuracy: 0.9905 - val_loss: 1.8106 - val_accuracy: 0.5926
# Epoch 13/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0842 - accuracy: 0.9844
# Epoch 00013: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0686 - accuracy: 0.9905 - val_loss: 1.7256 - val_accuracy: 0.5926
# Epoch 14/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0378 - accuracy: 1.0000
# Epoch 00014: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 1.6041 - val_accuracy: 0.5926
# Epoch 15/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0429 - accuracy: 1.0000
# Epoch 00015: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0636 - accuracy: 0.9905 - val_loss: 1.6538 - val_accuracy: 0.6296
# Epoch 16/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1367 - accuracy: 0.9375
# Epoch 00016: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1044 - accuracy: 0.9619 - val_loss: 1.9136 - val_accuracy: 0.6667
# Epoch 17/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1966 - accuracy: 0.9375
# Epoch 00017: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1330 - accuracy: 0.9619 - val_loss: 2.1301 - val_accuracy: 0.5185
# Epoch 18/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0726 - accuracy: 0.9844
# Epoch 00018: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0586 - accuracy: 0.9905 - val_loss: 2.2654 - val_accuracy: 0.4815
# Epoch 19/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0477 - accuracy: 0.9844
# Epoch 00019: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1059 - accuracy: 0.9619 - val_loss: 2.0608 - val_accuracy: 0.5926
# Epoch 20/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0360 - accuracy: 1.0000
# Epoch 00020: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2408 - accuracy: 0.9429 - val_loss: 1.7344 - val_accuracy: 0.6667
# Epoch 21/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2104 - accuracy: 0.9531
# Epoch 00021: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2007 - accuracy: 0.9524 - val_loss: 1.7713 - val_accuracy: 0.5926
# Epoch 22/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0648 - accuracy: 1.0000
# Epoch 00022: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0883 - accuracy: 0.9714 - val_loss: 1.9441 - val_accuracy: 0.5185
# Epoch 23/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2036 - accuracy: 0.9375
# Epoch 00023: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1638 - accuracy: 0.9524 - val_loss: 1.9478 - val_accuracy: 0.5926
# Epoch 24/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0957 - accuracy: 0.9688
# Epoch 00024: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0755 - accuracy: 0.9810 - val_loss: 2.1651 - val_accuracy: 0.5556
# Epoch 25/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1290 - accuracy: 0.9531
# Epoch 00025: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1152 - accuracy: 0.9524 - val_loss: 2.1380 - val_accuracy: 0.5926
# Epoch 26/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1066 - accuracy: 0.9531
# Epoch 00026: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0904 - accuracy: 0.9619 - val_loss: 1.8048 - val_accuracy: 0.6296
# Epoch 27/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0688 - accuracy: 0.9844
# Epoch 00027: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0527 - accuracy: 0.9905 - val_loss: 1.8031 - val_accuracy: 0.6667
# Epoch 28/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0499 - accuracy: 1.0000
# Epoch 00028: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0498 - accuracy: 0.9905 - val_loss: 1.9944 - val_accuracy: 0.5556
# Epoch 29/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0897 - accuracy: 0.9688
# Epoch 00029: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1006 - accuracy: 0.9619 - val_loss: 1.7974 - val_accuracy: 0.5926
# Epoch 30/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0424 - accuracy: 0.9844
# Epoch 00030: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0516 - accuracy: 0.9810 - val_loss: 1.6499 - val_accuracy: 0.5926
# Epoch 31/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0294 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 1.7040 - val_accuracy: 0.5926
# Epoch 32/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0597 - accuracy: 0.9844
# Epoch 00032: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0584 - accuracy: 0.9905 - val_loss: 1.7676 - val_accuracy: 0.5926
# Epoch 33/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0824 - accuracy: 0.9688
# Epoch 00033: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0618 - accuracy: 0.9810 - val_loss: 1.7054 - val_accuracy: 0.5556
# Epoch 34/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0324 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 1.6276 - val_accuracy: 0.5556
# Epoch 35/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 1.5640 - val_accuracy: 0.5926
# Epoch 36/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 1.5736 - val_accuracy: 0.5926
# Epoch 37/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000
# Epoch 00037: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0368 - accuracy: 0.9905 - val_loss: 1.6052 - val_accuracy: 0.5556
# Epoch 38/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0238 - accuracy: 1.0000
# Epoch 00038: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.6559 - val_accuracy: 0.5926
# Epoch 39/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0224 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.7212 - val_accuracy: 0.5926
# Epoch 40/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0300 - accuracy: 1.0000
# Epoch 00040: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 1.7941 - val_accuracy: 0.6296
# Epoch 41/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0351 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 1.8598 - val_accuracy: 0.6296
# Epoch 42/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0155 - accuracy: 1.0000
# Epoch 00042: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.9223 - val_accuracy: 0.5926
# Epoch 43/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0189 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.9754 - val_accuracy: 0.5926
# Epoch 44/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0209 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 1.9871 - val_accuracy: 0.5926
# Epoch 45/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.9758 - val_accuracy: 0.5926
# Epoch 46/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00046: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.9635 - val_accuracy: 0.6296
# Epoch 47/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0281 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.9480 - val_accuracy: 0.5926
# Epoch 48/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.9346 - val_accuracy: 0.5926
# Epoch 49/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.9069 - val_accuracy: 0.6296
# Epoch 50/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 00050: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.8755 - val_accuracy: 0.6296
# Epoch 51/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.8649 - val_accuracy: 0.6296
# Epoch 52/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 00052: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.8592 - val_accuracy: 0.6296
# Epoch 53/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.8576 - val_accuracy: 0.6296
# Epoch 54/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 00054: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.8548 - val_accuracy: 0.6296
# Epoch 55/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.8351 - val_accuracy: 0.6296
# Epoch 56/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.8277 - val_accuracy: 0.6296
# Epoch 57/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00057: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.8226 - val_accuracy: 0.5926
# Epoch 58/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.8239 - val_accuracy: 0.5926
# Epoch 59/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 00059: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.8261 - val_accuracy: 0.5926
# Epoch 60/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00060: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.8479 - val_accuracy: 0.5926
# Epoch 61/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.8893 - val_accuracy: 0.6667
# Epoch 62/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.9292 - val_accuracy: 0.6667
# Epoch 63/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.9679 - val_accuracy: 0.6667
# Epoch 64/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.9973 - val_accuracy: 0.6667
# Epoch 65/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.0132 - val_accuracy: 0.6667
# Epoch 66/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.0362 - val_accuracy: 0.6667
# Epoch 67/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 2.0545 - val_accuracy: 0.6296
# Epoch 68/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.0672 - val_accuracy: 0.6296
# Epoch 69/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 2.0739 - val_accuracy: 0.6296
# Epoch 70/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00070: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.0748 - val_accuracy: 0.6296
# Epoch 71/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 2.0711 - val_accuracy: 0.6296
# Epoch 72/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 2.0655 - val_accuracy: 0.6667
# Epoch 73/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 2.0584 - val_accuracy: 0.6667
# Epoch 74/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 2.0553 - val_accuracy: 0.6667
# Epoch 75/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.0366 - val_accuracy: 0.6667
# Epoch 76/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00076: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 2.0144 - val_accuracy: 0.6667
# Epoch 77/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.0108 - val_accuracy: 0.6296
# Epoch 78/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00078: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 2.0081 - val_accuracy: 0.6296
# Epoch 79/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.0057 - val_accuracy: 0.6296
# Epoch 80/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.1043 - val_accuracy: 0.6296
# Epoch 81/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 00081: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 2.1784 - val_accuracy: 0.5926
# Epoch 82/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00082: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 2.2278 - val_accuracy: 0.6296
# Epoch 83/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 2.2405 - val_accuracy: 0.6296
# Epoch 84/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0190 - accuracy: 0.9844
# Epoch 00084: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0149 - accuracy: 0.9905 - val_loss: 2.0726 - val_accuracy: 0.6296
# Epoch 85/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.9384 - val_accuracy: 0.6296
# Epoch 86/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.8130 - val_accuracy: 0.6296
# Epoch 87/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00087: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0498 - accuracy: 0.9905 - val_loss: 1.8203 - val_accuracy: 0.6296
# Epoch 88/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 00088: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0161 - accuracy: 0.9905 - val_loss: 2.0916 - val_accuracy: 0.6296
# Epoch 89/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00089: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.3407 - val_accuracy: 0.6296
# Epoch 90/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0641 - accuracy: 0.9844
# Epoch 00090: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0409 - accuracy: 0.9905 - val_loss: 2.3638 - val_accuracy: 0.6296
# Epoch 91/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0233 - accuracy: 0.9844
# Epoch 00091: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0168 - accuracy: 0.9905 - val_loss: 2.1989 - val_accuracy: 0.6296
# Epoch 92/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00092: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.0594 - val_accuracy: 0.6296
# Epoch 93/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.9409 - val_accuracy: 0.5926
# Epoch 94/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.8515 - val_accuracy: 0.5926
# Epoch 95/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7881 - val_accuracy: 0.5926
# Epoch 96/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.7678 - val_accuracy: 0.5926
# Epoch 97/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7839 - val_accuracy: 0.5926
# Epoch 98/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0204 - accuracy: 0.9844
# Epoch 00098: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0146 - accuracy: 0.9905 - val_loss: 1.7968 - val_accuracy: 0.5926
# Epoch 99/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.8300 - val_accuracy: 0.5556
# Epoch 100/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.8866 - val_accuracy: 0.5556
# Epoch 101/150
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00101: val_loss did not improve from 1.21495
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.9536 - val_accuracy: 0.6296

# %%
model.load_weights("best_emoji_model.h5")

# %%
model.evaluate(embeddings_matrix_test,y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4766 - accuracy: 0.6250
# [1.4765691757202148, 0.625]

# %%
pred=model.predict_classes(embeddings_matrix_test)

# %%
for i in range(30):
    print(' '.join(x_test[i]))
    print(emoji.emojize( emoji_dict[np.argmax(y_test[i])], use_aliases=True) )
    print(emoji.emojize(emoji_dict[pred[i]], use_aliases=True))
# Out:
# I want to eat
# 🍴
# 🍴
# he did not answer
# 😞
# 😞
# he got a raise
# 😄
# 😄
# she got me a present
# ❤
# ❤
# ha ha ha it was so funny
# 😄
# 😄
# he is a good friend
# ❤
# 😄
# I am upset
# ❤
# ⚾
# We had such a lovely dinner tonight
# ❤
# 😄
# where is the food
# 🍴
# 🍴
# Stop making this joke ha ha ha
# 😄
# 😄
# where is the ball
# ⚾
# ⚾
# work is hard
# 😞
# 😄
# This girl is messing with me
# 😞
# ❤
# are you serious ha ha
# 😄
# 😞
# Let us go play baseball
# ⚾
# ⚾
# This stupid grader is not working
# 😞
# 😞
# work is horrible
# 😞
# 😄
# Congratulation for having a baby
# 😄
# 😄
# stop messing around
# 😞
# 😞
# any suggestions for dinner
# 🍴
# 🍴
# I love taking breaks
# ❤
# ❤
# you brighten my day
# 😄
# ❤
# I boiled rice
# 🍴
# 🍴
# she is a bully
# 😞
# ❤
# Why are you feeling bad
# 😞
# 😞
# I am upset
# 😞
# ⚾
# I worked during my birthday
# 😞
# 😄
# My grandmother is the love of my life
# ❤
# ❤
# enjoy your break
# 😄
# 🍴
# valentine day is near
# ❤
# 😄
